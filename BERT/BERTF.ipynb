# %%
import os
import pandas as pd
from transformers import BertTokenizer

# Initialize tokenizer and label dictionary for conversion to BERT format
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
label2id = {'O': 0, 'B-[FILING_DATE]': 1, 'B-[COMPANY_NAME]': 2, 'I-[COMPANY_NAME]': 3, 'B-[COMPANY_NUMBER]': 4,
            'B-[RETURN_DATE]': 5, 'B-[SIC_CODES]': 6, 'B-[COMPANY_TYPE]': 7, 'B-[REGISTERED_ADDRESS]': 8,
            'I-[REGISTERED_ADDRESS]': 9}  # Add more labels as needed

# Initialize lists to store all data for BERT
input_ids = []
attention_masks = []
label_ids = []

# Define path to training data directory
train_path = os.path.join('datasetfiles', 'train')

# Process each pair of .txt and .csv files in the train folder
for filename in os.listdir(train_path):
    if filename.endswith('.txt'):
        # Load text data and corresponding labels file
        text_file_path = os.path.join(train_path, filename)
        label_file_path = os.path.join(train_path, filename.replace('.txt', '.csv'))

        with open(text_file_path, 'r') as file:
            text_data = file.read()

        labels_df = pd.read_csv(label_file_path)

        # Split the text data into sentences based on double newlines
        sentences = [sentence.strip() for sentence in text_data.split('\n\n') if sentence.strip()]

        # Clean up tokens in the labels DataFrame (remove extra quotes if any)
        labels_df['tokens'] = labels_df['tokens'].str.replace("'", "", regex=False)
        labels_df['labels'] = labels_df['labels'].str.replace("'", "", regex=False)

        # Initialize variables for organizing tokens and labels by sentence
        sentence_token_labels = []
        current_sentence_tokens = []
        current_sentence_labels = []
        sentence_index = 0
        sentence_length = len(sentences)

        # Iterate over each token-label pair in the labels dataframe
        for idx, row in labels_df.iterrows():
            token = row['tokens']
            label = row['labels']

            # Check if token belongs to the current sentence
            if sentence_index < sentence_length and token in sentences[sentence_index]:
                current_sentence_tokens.append(token)
                current_sentence_labels.append(label)
            else:
                # Finalize the current sentence grouping and move to the next
                sentence_token_labels.append((current_sentence_tokens, current_sentence_labels))
                current_sentence_tokens = [token]  # Start new sentence tokens
                current_sentence_labels = [label]
                sentence_index += 1

        # Capture any remaining tokens in the last sentence
        if current_sentence_tokens:
            sentence_token_labels.append((current_sentence_tokens, current_sentence_labels))

        # Convert sentence_token_labels into BERT-compatible format
        for tokens, labels in sentence_token_labels:
            # Tokenize and prepare inputs for BERT
            tokenized_input = tokenizer(tokens, is_split_into_words=True, padding='max_length', truncation=True, max_length=128)
            input_ids.append(tokenized_input['input_ids'])
            attention_masks.append(tokenized_input['attention_mask'])

            # Convert labels to label IDs
            label_id = [label2id.get(label, 0) for label in labels]
            # Pad labels to match max sequence length
            label_id += [0] * (128 - len(label_id))  # Pad to max_length if needed
            label_ids.append(label_id)

# The variables input_ids, attention_masks, and label_ids are now ready for training
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
import torch
from transformers import BertForTokenClassification, BertTokenizer, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader

# Define custom dataset for PyTorch
class NERDataset(Dataset):
    def __init__(self, input_ids, attention_masks, label_ids):
        self.input_ids = input_ids
        self.attention_masks = attention_masks
        self.label_ids = label_ids

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
            'labels': torch.tensor(self.label_ids[idx], dtype=torch.long)
        }

# Initialize dataset and dataloader
train_dataset = NERDataset(input_ids, attention_masks, label_ids)
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# Load BERT for token classification
model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=len(label2id))
os.environ["WANDB_DISABLED"] = "true"
# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=3,              # number of training epochs
    per_device_train_batch_size=8,   # batch size for training
    per_device_eval_batch_size=8,    # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,
)

# Initialize Trainer
trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset          # training dataset
)

# Train the model
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
#     <div>
#
#       <progress value='1356' max='1356' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1356/1356 05:55, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.374600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.274900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.016200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.629900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.976800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.358500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.089800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.024300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.003100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.009200</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.003500</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.011500</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.009900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.000800</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.000800</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>124
# TrainOutput(global_step=1356, training_loss=0.07317735461333072, metrics={'train_runtime': 356.9444, 'train_samples_per_second': 30.332, 'train_steps_per_second': 3.799, 'total_flos': 707316151011840.0, 'train_loss': 0.07317735461333072, 'epoch': 3.0})

# %%
model.save_pretrained("./fine_tuned_model")
tokenizer.save_pretrained("./fine_tuned_model")
# Out:
# ('./fine_tuned_model/tokenizer_config.json',
#  './fine_tuned_model/special_tokens_map.json',
#  './fine_tuned_model/vocab.txt',
#  './fine_tuned_model/added_tokens.json')

# %%
# Load and process test text and labels
with open('datasetfiles/test/doc_5.txt', 'r') as file:
    test_text_data = file.read()

test_labels_df = pd.read_csv('datasetfiles/test/doc_5.csv')

# Split test text data into sentences
test_sentences = [sentence.strip() for sentence in test_text_data.split('\n\n') if sentence.strip()]

# Clean up tokens in the labels DataFrame (remove extra quotes if any)
test_labels_df['tokens'] = test_labels_df['tokens'].str.replace("'", "", regex=False)
test_labels_df['labels'] = test_labels_df['labels'].str.replace("'", "", regex=False)

# Initialize variables for test token and label alignment
test_sentence_token_labels = []
current_sentence_tokens = []
current_sentence_labels = []
test_sentence_index = 0
test_sentence_length = len(test_sentences)

# Align test tokens with sentences
for idx, row in test_labels_df.iterrows():
    token = row['tokens']
    label = row['labels']

    if test_sentence_index < test_sentence_length and token in test_sentences[test_sentence_index]:
        current_sentence_tokens.append(token)
        current_sentence_labels.append(label)
    else:
        test_sentence_token_labels.append((current_sentence_tokens, current_sentence_labels))
        current_sentence_tokens = [token]
        current_sentence_labels = [label]
        test_sentence_index += 1

# Capture remaining tokens
if current_sentence_tokens:
    test_sentence_token_labels.append((current_sentence_tokens, current_sentence_labels))

# Tokenize and prepare test data for BERT
test_input_ids = []
test_attention_masks = []
test_label_ids = []

for tokens, labels in test_sentence_token_labels:
    tokenized_input = tokenizer(tokens, is_split_into_words=True, padding='max_length', truncation=True, max_length=128)
    test_input_ids.append(tokenized_input['input_ids'])
    test_attention_masks.append(tokenized_input['attention_mask'])

    label_id = [label2id.get(label, 0) for label in labels]
    label_id += [0] * (128 - len(label_id))
    test_label_ids.append(label_id)

# Define test dataset
test_dataset = NERDataset(test_input_ids, test_attention_masks, test_label_ids)

# Evaluate model on test dataset
trainer.evaluate(eval_dataset=test_dataset)
# Out:
#     <div>
#
#       <progress value='113' max='113' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [113/113 00:06]
#     </div>
# {'eval_loss': 0.0003189194540027529,
#  'eval_runtime': 6.1107,
#  'eval_samples_per_second': 147.447,
#  'eval_steps_per_second': 18.492,
#  'epoch': 3.0}

# %%
# Define id2label dictionary to map IDs back to label names
id2label = {v: k for k, v in label2id.items()}

# Get predictions using Trainer
predictions = trainer.predict(test_dataset)

# Extract predicted label IDs
pred_label_ids = predictions.predictions.argmax(-1)
true_label_ids = predictions.label_ids

# Convert label IDs to label names
pred_labels = [[id2label[label_id] for label_id in sentence] for sentence in pred_label_ids]
true_labels = [[id2label[label_id] for label_id in sentence] for sentence in true_label_ids]

# Display a few sample predictions with true labels for comparison
for i in range(3):  # Display first 3 examples
    print("Tokens: ", test_sentence_token_labels[i][0])
    print("True Labels: ", true_labels[i])
    print("Predicted Labels: ", pred_labels[i])
    print()
# Out:
# Tokens:  ['Companies', 'House', 'ARO', '1', '(ef)']
# True Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predicted Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Tokens:  ['Annual', 'Return']
# True Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predicted Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Tokens:  ['Received', 'for', 'filing', 'in', 'Electronic', 'Format', 'on', 'the:', '13/04/2022', 'X4LE264B', 'Company', 'Name:', 'ALLIANCE', 'PARTNERS', 'LIMITED', 'LIABILITY', 'PARTNERSHIP', 'Company', 'Number:', '8283180', 'Date', 'of', 'this', 'return:', '30/03/2022', 'SIC', 'codes:', '71027', 'Company', 'Type:', 'LIMITED', 'LIABILITY', 'PARTNERSHIP', 'Situation', 'of', 'Registered', 'Office:', '7', 'Victoria', 'Street', 'Brighton', 'X34', '8AT', 'United', 'Kingdom']
# True Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-[FILING_DATE]', 'O', 'O', 'O', 'B-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'O', 'O', 'B-[COMPANY_NUMBER]', 'O', 'O', 'O', 'O', 'B-[RETURN_DATE]', 'O', 'O', 'B-[SIC_CODES]', 'O', 'O', 'B-[COMPANY_TYPE]', 'O', 'O', 'O', 'O', 'O', 'O', 'B-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Predicted Labels:  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-[FILING_DATE]', 'O', 'O', 'O', 'B-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'I-[COMPANY_NAME]', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-[SIC_CODES]', 'O', 'O', 'B-[COMPANY_TYPE]', 'O', 'O', 'O', 'O', 'O', 'O', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'I-[REGISTERED_ADDRESS]', 'O', 'I-[REGISTERED_ADDRESS]', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
# Iterate through each example and display only correct predictions
for i in range(len(test_sentence_token_labels)):
    tokens = test_sentence_token_labels[i][0]
    true_label_sequence = true_labels[i]
    pred_label_sequence = pred_labels[i]

    # Filter correct predictions (where true label matches predicted label)
    correct_predictions = [
        (token, true_label, pred_label)
        for token, true_label, pred_label in zip(tokens, true_label_sequence, pred_label_sequence)
        if true_label == pred_label
    ]

    # Display correct predictions for the current example
    if correct_predictions:
        print(f"Example {i + 1} - Correct Predictions:")
        for token, true_label, pred_label in correct_predictions:
            print(f"Token: {token}, True Label: {true_label}, Predicted Label: {pred_label}")
        print()
# Out:
# Example 1 - Correct Predictions:
# Token: Companies, True Label: O, Predicted Label: O
# Token: House, True Label: O, Predicted Label: O
# Token: ARO, True Label: O, Predicted Label: O
# Token: 1, True Label: O, Predicted Label: O
# Token: (ef), True Label: O, Predicted Label: O
#
# Example 2 - Correct Predictions:
# Token: Annual, True Label: O, Predicted Label: O
# Token: Return, True Label: O, Predicted Label: O
#
# Example 3 - Correct Predictions:
# Token: Received, True Label: O, Predicted Label: O
# Token: for, True Label: O, Predicted Label: O
# Token: filing, True Label: O, Predicted Label: O
# Token: in, True Label: O, Predicted Label: O
# Token: Electronic, True Label: O, Predicted Label: O
# Token: Format, True Label: O, Predicted Label: O
# Token: on, True Label: O, Predicted Label: O
# Token: the:, True Label: O, Predicted Label: O
# Token: 13/04/2022, True Label: B-[FILING_DATE], Predicted Label: B-[FILING_DATE]
# Token: X4LE264B, True Label: O, Predicted Label: O
# Token: Company, True Label: O, Predicted Label: O
# Token: Name:, True Label: O, Predicted Label: O
# Token: ALLIANCE, True Label: B-[COMPANY_NAME], Predicted Label: B-[COMPANY_NAME]
# Token: PARTNERS, True Label: I-[COMPANY_NAME], Predicted Label: I-[COMPANY_NAME]
# Token: LIMITED, True Label: I-[COMPANY_NAME], Predicted Label: I-[COMPANY_NAME]
# Token: Company, True Label: O, Predicted Label: O
# Token: Number:, True Label: O, Predicted Label: O
# Token: Date, True Label: O, Predicted Label: O
# Token: of, True Label: O, Predicted Label: O
# Token: this, True Label: O, Predicted Label: O
# Token: return:, True Label: O, Predicted Label: O
# Token: SIC, True Label: O, Predicted Label: O
# Token: codes:, True Label: O, Predicted Label: O
# Token: 71027, True Label: B-[SIC_CODES], Predicted Label: B-[SIC_CODES]
# Token: Company, True Label: O, Predicted Label: O
# Token: Type:, True Label: O, Predicted Label: O
# Token: LIMITED, True Label: B-[COMPANY_TYPE], Predicted Label: B-[COMPANY_TYPE]
# Token: LIABILITY, True Label: O, Predicted Label: O
# Token: PARTNERSHIP, True Label: O, Predicted Label: O
# Token: Situation, True Label: O, Predicted Label: O
# Token: of, True Label: O, Predicted Label: O
# Token: Registered, True Label: O, Predicted Label: O
# Token: Office:, True Label: O, Predicted Label: O
# Token: Victoria, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Street, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Brighton, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: X34, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: 8AT, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Kingdom, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
#
# Example 4 - Correct Predictions:
# Token: Officers, True Label: O, Predicted Label: O
# Token: of, True Label: O, Predicted Label: O
# Token: the, True Label: O, Predicted Label: O
# Token: company, True Label: O, Predicted Label: O
#
# Example 5 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
# Token: Filed, True Label: O, Predicted Label: O
# Token: Document, True Label: O, Predicted Label: O
# Token: for, True Label: O, Predicted Label: O
# Token: Company, True Label: O, Predicted Label: O
# Token: Number:, True Label: O, Predicted Label: O
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
# Token: Page:1, True Label: O, Predicted Label: O
# Token: Company, True Label: O, Predicted Label: O
#
# Example 6 - Correct Predictions:
# Token: Secretary, True Label: O, Predicted Label: O
# Token: 5, True Label: O, Predicted Label: O
#
# Example 7 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
# Token: Person, True Label: O, Predicted Label: O
#
# Example 8 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
# Token: forename(s):, True Label: O, Predicted Label: O
# Token: ANTHONY, True Label: O, Predicted Label: O
# Token: Surname:, True Label: O, Predicted Label: O
# Token: MILLER, True Label: O, Predicted Label: O
#
# Example 9 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
# Token: names:, True Label: O, Predicted Label: O
#
# Example 10 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
# Token: Address, True Label: O, Predicted Label: O
# Token: recorded, True Label: O, Predicted Label: O
# Token: as, True Label: O, Predicted Label: O
#
# Example 11 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 12 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 13 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
# Token: Company, True Label: O, Predicted Label: O
#
# Example 14 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 15 - Correct Predictions:
# Token: 41, True Label: O, Predicted Label: O
#
# Example 16 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 17 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 18 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 19 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 20 - Correct Predictions:
# Token: MICHAEL, True Label: O, Predicted Label: O
#
# Example 21 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 22 - Correct Predictions:
# Token: ROBINSON, True Label: O, Predicted Label: O
#
# Example 23 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 24 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 25 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 26 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 27 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 28 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 29 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
# Token: registered, True Label: O, Predicted Label: O
# Token: office, True Label: O, Predicted Label: O
#
# Example 30 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
# Token: Usually, True Label: O, Predicted Label: O
# Token: Resident:, True Label: O, Predicted Label: O
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 31 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 32 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 33 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 34 - Correct Predictions:
# Token: **/03/1967, True Label: O, Predicted Label: O
#
# Example 35 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 36 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 37 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 38 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 39 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 40 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 41 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 42 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 43 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 44 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 45 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 46 - Correct Predictions:
# Token: Page:2, True Label: O, Predicted Label: O
# Token: Company, True Label: O, Predicted Label: O
#
# Example 47 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 48 - Correct Predictions:
# Token: 42, True Label: O, Predicted Label: O
# Token: Type:, True Label: O, Predicted Label: O
# Token: Person, True Label: O, Predicted Label: O
#
# Example 49 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 50 - Correct Predictions:
# Token: CHARLES, True Label: O, Predicted Label: O
#
# Example 51 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 52 - Correct Predictions:
# Token: MILLER, True Label: O, Predicted Label: O
#
# Example 53 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 54 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 55 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 56 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 57 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 58 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 59 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
# Token: registered, True Label: O, Predicted Label: O
# Token: office, True Label: O, Predicted Label: O
#
# Example 60 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
# Token: Usually, True Label: O, Predicted Label: O
# Token: Resident:, True Label: O, Predicted Label: O
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 61 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 62 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 63 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 64 - Correct Predictions:
# Token: **/03/1970, True Label: O, Predicted Label: O
#
# Example 65 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 66 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 67 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 68 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
# Token: Date, True Label: O, Predicted Label: O
# Token: of, True Label: O, Predicted Label: O
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 69 - Correct Predictions:
# Token: **/06/1946, True Label: O, Predicted Label: O
# Token: Nationality:, True Label: O, Predicted Label: O
# Token: BRITISH, True Label: O, Predicted Label: O
# Token: Occupation:, True Label: O, Predicted Label: O
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 70 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
# Token: Director, True Label: O, Predicted Label: O
#
# Example 71 - Correct Predictions:
# Token: 43, True Label: O, Predicted Label: O
# Token: Type:, True Label: O, Predicted Label: O
# Token: Person, True Label: O, Predicted Label: O
#
# Example 72 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 73 - Correct Predictions:
# Token: RONALD, True Label: O, Predicted Label: O
#
# Example 74 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 75 - Correct Predictions:
# Token: ROBINSON, True Label: O, Predicted Label: O
#
# Example 76 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 77 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 78 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 79 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 80 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
# Token: as, True Label: O, Predicted Label: O
#
# Example 81 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 82 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 83 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 84 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 85 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 86 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 87 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 88 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 89 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 90 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 91 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 92 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 93 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 94 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 95 - Correct Predictions:
# Token: Page:3, True Label: O, Predicted Label: O
#
# Example 96 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 97 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 98 - Correct Predictions:
# Token: 44, True Label: O, Predicted Label: O
#
# Example 99 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 100 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
# Token: Full, True Label: O, Predicted Label: O
#
# Example 101 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 102 - Correct Predictions:
# Token: RICHARD, True Label: O, Predicted Label: O
#
# Example 103 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
# Token: HARRIS, True Label: O, Predicted Label: O
#
# Example 104 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 105 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 106 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 107 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 108 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 109 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 110 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 111 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 112 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 113 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 114 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 115 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 116 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 117 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 118 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 119 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 120 - Correct Predictions:
# Token: **/08/1957, True Label: O, Predicted Label: O
#
# Example 121 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 122 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 123 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 124 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 125 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 126 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 127 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 128 - Correct Predictions:
# Token: **/04/1936, True Label: O, Predicted Label: O
#
# Example 129 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 130 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 131 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 132 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 133 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 134 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 135 - Correct Predictions:
# Token: 45, True Label: O, Predicted Label: O
#
# Example 136 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 137 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 138 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 139 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 140 - Correct Predictions:
# Token: THOMAS, True Label: O, Predicted Label: O
#
# Example 141 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 142 - Correct Predictions:
# Token: THOMAS, True Label: O, Predicted Label: O
#
# Example 143 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 144 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 145 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 146 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 147 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 148 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 149 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 150 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 151 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 152 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 153 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 154 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 155 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 156 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 157 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 158 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 159 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 160 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 161 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 162 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 163 - Correct Predictions:
# Token: Page:4, True Label: O, Predicted Label: O
#
# Example 164 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 165 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 166 - Correct Predictions:
# Token: 46, True Label: O, Predicted Label: O
#
# Example 167 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 168 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 169 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 170 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 171 - Correct Predictions:
# Token: DANIEL, True Label: O, Predicted Label: O
#
# Example 172 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 173 - Correct Predictions:
# Token: JONES, True Label: O, Predicted Label: O
#
# Example 174 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 175 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 176 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 177 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 178 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 179 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 180 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 181 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 182 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 183 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 184 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 185 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 186 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 187 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 188 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 189 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 190 - Correct Predictions:
# Token: **/01/1971, True Label: O, Predicted Label: O
#
# Example 191 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 192 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 193 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 194 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 195 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 196 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 197 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 198 - Correct Predictions:
# Token: **/08/1948, True Label: O, Predicted Label: O
#
# Example 199 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 200 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 201 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 202 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 203 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 204 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 205 - Correct Predictions:
# Token: 47, True Label: O, Predicted Label: O
#
# Example 206 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 207 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 208 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 209 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 210 - Correct Predictions:
# Token: EDWARD, True Label: O, Predicted Label: O
#
# Example 211 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 212 - Correct Predictions:
# Token: ANDERSON, True Label: O, Predicted Label: O
#
# Example 213 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 214 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 215 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 216 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 217 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 218 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 219 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 220 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 221 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 222 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 223 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 224 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 225 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 226 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 227 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 228 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 229 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 230 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 231 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 232 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 233 - Correct Predictions:
# Token: Page:5, True Label: O, Predicted Label: O
#
# Example 234 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 235 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 236 - Correct Predictions:
# Token: 48, True Label: O, Predicted Label: O
#
# Example 237 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 238 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 239 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 240 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 241 - Correct Predictions:
# Token: ANTHONY, True Label: O, Predicted Label: O
#
# Example 242 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 243 - Correct Predictions:
# Token: ANDERSON, True Label: O, Predicted Label: O
#
# Example 244 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 245 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 246 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 247 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 248 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 249 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 250 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 251 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 252 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 253 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 254 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 255 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 256 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 257 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 258 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 259 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 260 - Correct Predictions:
# Token: **/07/1960, True Label: O, Predicted Label: O
#
# Example 261 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 262 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 263 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 264 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 265 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 266 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 267 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 268 - Correct Predictions:
# Token: **/07/1947, True Label: O, Predicted Label: O
#
# Example 269 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 270 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 271 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 272 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 273 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 274 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 275 - Correct Predictions:
# Token: 49, True Label: O, Predicted Label: O
#
# Example 276 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 277 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 278 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 279 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 280 - Correct Predictions:
# Token: ANTHONY, True Label: O, Predicted Label: O
#
# Example 281 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 282 - Correct Predictions:
# Token: WHITE, True Label: O, Predicted Label: O
#
# Example 283 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 284 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 285 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 286 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 287 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 288 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 289 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 290 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 291 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 292 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 293 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 294 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 295 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 296 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 297 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 298 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 299 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 300 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 301 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 302 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 303 - Correct Predictions:
# Token: Page:6, True Label: O, Predicted Label: O
#
# Example 304 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 305 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 306 - Correct Predictions:
# Token: 50, True Label: O, Predicted Label: O
#
# Example 307 - Correct Predictions:
# Token: Type:, True Label: O, Predicted Label: O
#
# Example 308 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 309 - Correct Predictions:
# Token: Full, True Label: O, Predicted Label: O
#
# Example 310 - Correct Predictions:
# Token: forename(s):, True Label: O, Predicted Label: O
#
# Example 311 - Correct Predictions:
# Token: CHARLES, True Label: O, Predicted Label: O
#
# Example 312 - Correct Predictions:
# Token: Surname:, True Label: O, Predicted Label: O
#
# Example 313 - Correct Predictions:
# Token: WILLIAMS, True Label: O, Predicted Label: O
#
# Example 314 - Correct Predictions:
# Token: Former, True Label: O, Predicted Label: O
#
# Example 315 - Correct Predictions:
# Token: names:, True Label: O, Predicted Label: O
#
# Example 316 - Correct Predictions:
# Token: Service, True Label: O, Predicted Label: O
#
# Example 317 - Correct Predictions:
# Token: Address, True Label: O, Predicted Label: O
#
# Example 318 - Correct Predictions:
# Token: recorded, True Label: O, Predicted Label: O
#
# Example 319 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 320 - Correct Predictions:
# Token: Companys, True Label: O, Predicted Label: O
#
# Example 321 - Correct Predictions:
# Token: registered, True Label: O, Predicted Label: O
#
# Example 322 - Correct Predictions:
# Token: office, True Label: O, Predicted Label: O
#
# Example 323 - Correct Predictions:
# Token: Country/State, True Label: O, Predicted Label: O
#
# Example 324 - Correct Predictions:
# Token: Usually, True Label: O, Predicted Label: O
#
# Example 325 - Correct Predictions:
# Token: Resident:, True Label: O, Predicted Label: O
#
# Example 326 - Correct Predictions:
# Token: ENGLAND, True Label: O, Predicted Label: O
#
# Example 327 - Correct Predictions:
# Token: Date, True Label: O, Predicted Label: O
#
# Example 328 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 329 - Correct Predictions:
# Token: Birth:, True Label: O, Predicted Label: O
#
# Example 330 - Correct Predictions:
# Token: **/03/1972, True Label: O, Predicted Label: O
#
# Example 331 - Correct Predictions:
# Token: Nationality:, True Label: O, Predicted Label: O
#
# Example 332 - Correct Predictions:
# Token: BRITISH, True Label: O, Predicted Label: O
#
# Example 333 - Correct Predictions:
# Token: Occupation:, True Label: O, Predicted Label: O
#
# Example 334 - Correct Predictions:
# Token: DIRECTOR, True Label: O, Predicted Label: O
#
# Example 335 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 336 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 337 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 338 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 339 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 340 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 341 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 342 - Correct Predictions:
# Token: Page:7, True Label: O, Predicted Label: O
#
# Example 343 - Correct Predictions:
# Token: Statement, True Label: O, Predicted Label: O
#
# Example 344 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 345 - Correct Predictions:
# Token: Capital, True Label: O, Predicted Label: O
#
# Example 346 - Correct Predictions:
# Token: (Share, True Label: O, Predicted Label: O
#
# Example 347 - Correct Predictions:
# Token: Capital), True Label: O, Predicted Label: O
#
# Example 348 - Correct Predictions:
# Token: Class, True Label: O, Predicted Label: O
#
# Example 349 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 350 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 351 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 352 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 353 - Correct Predictions:
# Token: Number, True Label: O, Predicted Label: O
#
# Example 354 - Correct Predictions:
# Token: allotted, True Label: O, Predicted Label: O
#
# Example 355 - Correct Predictions:
# Token: 536012, True Label: O, Predicted Label: O
#
# Example 356 - Correct Predictions:
# Token: Aggregate, True Label: O, Predicted Label: O
#
# Example 357 - Correct Predictions:
# Token: nominal, True Label: O, Predicted Label: O
#
# Example 358 - Correct Predictions:
# Token: 80233, True Label: O, Predicted Label: O
#
# Example 359 - Correct Predictions:
# Token: value, True Label: O, Predicted Label: O
#
# Example 360 - Correct Predictions:
# Token: Currency, True Label: O, Predicted Label: O
#
# Example 361 - Correct Predictions:
# Token: GBP, True Label: O, Predicted Label: O
#
# Example 362 - Correct Predictions:
# Token: Amount, True Label: O, Predicted Label: O
#
# Example 363 - Correct Predictions:
# Token: paid, True Label: O, Predicted Label: O
#
# Example 364 - Correct Predictions:
# Token: per, True Label: O, Predicted Label: O
#
# Example 365 - Correct Predictions:
# Token: share, True Label: O, Predicted Label: O
#
# Example 366 - Correct Predictions:
# Token: 0.25, True Label: O, Predicted Label: O
#
# Example 367 - Correct Predictions:
# Token: Amount, True Label: O, Predicted Label: O
#
# Example 368 - Correct Predictions:
# Token: unpaid, True Label: O, Predicted Label: O
#
# Example 369 - Correct Predictions:
# Token: per, True Label: O, Predicted Label: O
#
# Example 370 - Correct Predictions:
# Token: share, True Label: O, Predicted Label: O
#
# Example 371 - Correct Predictions:
# Token: 9, True Label: O, Predicted Label: O
#
# Example 372 - Correct Predictions:
# Token: Prescribed, True Label: O, Predicted Label: O
#
# Example 373 - Correct Predictions:
# Token: particulars, True Label: O, Predicted Label: O
#
# Example 374 - Correct Predictions:
# Token: ON, True Label: O, Predicted Label: O
#
# Example 375 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 376 - Correct Predictions:
# Token: SHOW, True Label: O, Predicted Label: O
#
# Example 377 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 378 - Correct Predictions:
# Token: HANDS, True Label: O, Predicted Label: O
#
# Example 379 - Correct Predictions:
# Token: EVERY, True Label: O, Predicted Label: O
#
# Example 380 - Correct Predictions:
# Token: MEMBER, True Label: O, Predicted Label: O
#
# Example 381 - Correct Predictions:
# Token: PRESENT, True Label: O, Predicted Label: O
#
# Example 382 - Correct Predictions:
# Token: IN, True Label: O, Predicted Label: O
#
# Example 383 - Correct Predictions:
# Token: PERSON, True Label: O, Predicted Label: O
#
# Example 384 - Correct Predictions:
# Token: SHALL, True Label: O, Predicted Label: O
#
# Example 385 - Correct Predictions:
# Token: HAVE, True Label: O, Predicted Label: O
#
# Example 386 - Correct Predictions:
# Token: ONE, True Label: O, Predicted Label: O
#
# Example 387 - Correct Predictions:
# Token: VOTE, True Label: O, Predicted Label: O
#
# Example 388 - Correct Predictions:
# Token: AND, True Label: O, Predicted Label: O
#
# Example 389 - Correct Predictions:
# Token: ON, True Label: O, Predicted Label: O
#
# Example 390 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 391 - Correct Predictions:
# Token: POLL, True Label: O, Predicted Label: O
#
# Example 392 - Correct Predictions:
# Token: EVERY, True Label: O, Predicted Label: O
#
# Example 393 - Correct Predictions:
# Token: MEMBER, True Label: O, Predicted Label: O
#
# Example 394 - Correct Predictions:
# Token: SHALL, True Label: O, Predicted Label: O
#
# Example 395 - Correct Predictions:
# Token: HAVE, True Label: O, Predicted Label: O
#
# Example 396 - Correct Predictions:
# Token: ONE, True Label: O, Predicted Label: O
#
# Example 397 - Correct Predictions:
# Token: VOTE, True Label: O, Predicted Label: O
#
# Example 398 - Correct Predictions:
# Token: FOR, True Label: O, Predicted Label: O
#
# Example 399 - Correct Predictions:
# Token: EACH, True Label: O, Predicted Label: O
#
# Example 400 - Correct Predictions:
# Token: SHARE, True Label: O, Predicted Label: O
#
# Example 401 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 402 - Correct Predictions:
# Token: WHICH, True Label: O, Predicted Label: O
#
# Example 403 - Correct Predictions:
# Token: HE, True Label: O, Predicted Label: O
#
# Example 404 - Correct Predictions:
# Token: IS, True Label: O, Predicted Label: O
#
# Example 405 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 406 - Correct Predictions:
# Token: HOLDER., True Label: O, Predicted Label: O
#
# Example 407 - Correct Predictions:
# Token: ON, True Label: O, Predicted Label: O
#
# Example 408 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 409 - Correct Predictions:
# Token: POLL, True Label: O, Predicted Label: O
#
# Example 410 - Correct Predictions:
# Token: VOTES, True Label: O, Predicted Label: O
#
# Example 411 - Correct Predictions:
# Token: MAY, True Label: O, Predicted Label: O
#
# Example 412 - Correct Predictions:
# Token: BE, True Label: O, Predicted Label: O
#
# Example 413 - Correct Predictions:
# Token: GIVEN, True Label: O, Predicted Label: O
#
# Example 414 - Correct Predictions:
# Token: EITHER, True Label: O, Predicted Label: O
#
# Example 415 - Correct Predictions:
# Token: PERSONALLY, True Label: O, Predicted Label: O
#
# Example 416 - Correct Predictions:
# Token: OR, True Label: O, Predicted Label: O
#
# Example 417 - Correct Predictions:
# Token: BY, True Label: O, Predicted Label: O
#
# Example 418 - Correct Predictions:
# Token: PROXY., True Label: O, Predicted Label: O
#
# Example 419 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 420 - Correct Predictions:
# Token: PROXY, True Label: O, Predicted Label: O
#
# Example 421 - Correct Predictions:
# Token: NEED, True Label: O, Predicted Label: O
#
# Example 422 - Correct Predictions:
# Token: NOT, True Label: O, Predicted Label: O
#
# Example 423 - Correct Predictions:
# Token: BE, True Label: O, Predicted Label: O
#
# Example 424 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 425 - Correct Predictions:
# Token: MEMBER, True Label: O, Predicted Label: O
#
# Example 426 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 427 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 428 - Correct Predictions:
# Token: COMPANY., True Label: O, Predicted Label: O
#
# Example 429 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 430 - Correct Predictions:
# Token: COMPANY, True Label: O, Predicted Label: O
#
# Example 431 - Correct Predictions:
# Token: MAY, True Label: O, Predicted Label: O
#
# Example 432 - Correct Predictions:
# Token: BY, True Label: O, Predicted Label: O
#
# Example 433 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 434 - Correct Predictions:
# Token: RESOLUTION, True Label: O, Predicted Label: O
#
# Example 435 - Correct Predictions:
# Token: DECLARE, True Label: O, Predicted Label: O
#
# Example 436 - Correct Predictions:
# Token: DIVIDENDS, True Label: O, Predicted Label: O
#
# Example 437 - Correct Predictions:
# Token: IN, True Label: O, Predicted Label: O
#
# Example 438 - Correct Predictions:
# Token: ACCORDANCE, True Label: O, Predicted Label: O
#
# Example 439 - Correct Predictions:
# Token: WITH, True Label: O, Predicted Label: O
#
# Example 440 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 441 - Correct Predictions:
# Token: RESPECTIVE, True Label: O, Predicted Label: O
#
# Example 442 - Correct Predictions:
# Token: RIGHTS, True Label: O, Predicted Label: O
#
# Example 443 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 444 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 445 - Correct Predictions:
# Token: MEMBERS, True Label: O, Predicted Label: O
#
# Example 446 - Correct Predictions:
# Token: BUT, True Label: O, Predicted Label: O
#
# Example 447 - Correct Predictions:
# Token: NO, True Label: O, Predicted Label: O
#
# Example 448 - Correct Predictions:
# Token: DIVIDEND, True Label: O, Predicted Label: O
#
# Example 449 - Correct Predictions:
# Token: SHALL, True Label: O, Predicted Label: O
#
# Example 450 - Correct Predictions:
# Token: EXCEED, True Label: O, Predicted Label: O
#
# Example 451 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 452 - Correct Predictions:
# Token: AMOUNT, True Label: O, Predicted Label: O
#
# Example 453 - Correct Predictions:
# Token: RECOMMENDED, True Label: O, Predicted Label: O
#
# Example 454 - Correct Predictions:
# Token: BY, True Label: O, Predicted Label: O
#
# Example 455 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 456 - Correct Predictions:
# Token: DIRECTORS., True Label: O, Predicted Label: O
#
# Example 457 - Correct Predictions:
# Token: IF, True Label: O, Predicted Label: O
#
# Example 458 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 459 - Correct Predictions:
# Token: COMPANY, True Label: O, Predicted Label: O
#
# Example 460 - Correct Predictions:
# Token: IS, True Label: O, Predicted Label: O
#
# Example 461 - Correct Predictions:
# Token: WOUND, True Label: O, Predicted Label: O
#
# Example 462 - Correct Predictions:
# Token: UP, True Label: O, Predicted Label: O
#
# Example 463 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 464 - Correct Predictions:
# Token: LIQUIDATOR, True Label: O, Predicted Label: O
#
# Example 465 - Correct Predictions:
# Token: MAY, True Label: O, Predicted Label: O
#
# Example 466 - Correct Predictions:
# Token: DIVIDE, True Label: O, Predicted Label: O
#
# Example 467 - Correct Predictions:
# Token: AMONG, True Label: O, Predicted Label: O
#
# Example 468 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 469 - Correct Predictions:
# Token: MEMBERS, True Label: O, Predicted Label: O
#
# Example 470 - Correct Predictions:
# Token: IN, True Label: O, Predicted Label: O
#
# Example 471 - Correct Predictions:
# Token: SPECIE, True Label: O, Predicted Label: O
#
# Example 472 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 473 - Correct Predictions:
# Token: WHOLE, True Label: O, Predicted Label: O
#
# Example 474 - Correct Predictions:
# Token: OR, True Label: O, Predicted Label: O
#
# Example 475 - Correct Predictions:
# Token: ANY, True Label: O, Predicted Label: O
#
# Example 476 - Correct Predictions:
# Token: PART, True Label: O, Predicted Label: O
#
# Example 477 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 478 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 479 - Correct Predictions:
# Token: ASSETS, True Label: O, Predicted Label: O
#
# Example 480 - Correct Predictions:
# Token: OF, True Label: O, Predicted Label: O
#
# Example 481 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 482 - Correct Predictions:
# Token: COMPANY, True Label: O, Predicted Label: O
#
# Example 483 - Correct Predictions:
# Token: AND, True Label: O, Predicted Label: O
#
# Example 484 - Correct Predictions:
# Token: MAY, True Label: O, Predicted Label: O
#
# Example 485 - Correct Predictions:
# Token: FOR, True Label: O, Predicted Label: O
#
# Example 486 - Correct Predictions:
# Token: THAT, True Label: O, Predicted Label: O
#
# Example 487 - Correct Predictions:
# Token: PURPOSE, True Label: O, Predicted Label: O
#
# Example 488 - Correct Predictions:
# Token: VALUE, True Label: O, Predicted Label: O
#
# Example 489 - Correct Predictions:
# Token: ANY, True Label: O, Predicted Label: O
#
# Example 490 - Correct Predictions:
# Token: ASSETS, True Label: O, Predicted Label: O
#
# Example 491 - Correct Predictions:
# Token: AND, True Label: O, Predicted Label: O
#
# Example 492 - Correct Predictions:
# Token: DETERMINE, True Label: O, Predicted Label: O
#
# Example 493 - Correct Predictions:
# Token: HOW, True Label: O, Predicted Label: O
#
# Example 494 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# Example 495 - Correct Predictions:
# Token: DIVISION, True Label: O, Predicted Label: O
#
# Example 496 - Correct Predictions:
# Token: SHALL, True Label: O, Predicted Label: O
#
# Example 497 - Correct Predictions:
# Token: BE, True Label: O, Predicted Label: O
#
# Example 498 - Correct Predictions:
# Token: CARRIED, True Label: O, Predicted Label: O
#
# Example 499 - Correct Predictions:
# Token: OUT, True Label: O, Predicted Label: O
#
# Example 500 - Correct Predictions:
# Token: AS, True Label: O, Predicted Label: O
#
# Example 501 - Correct Predictions:
# Token: BETWEEN, True Label: O, Predicted Label: O
#
# Example 502 - Correct Predictions:
# Token: THE, True Label: O, Predicted Label: O
#
# ...
#
# Example 712 - Correct Predictions:
# Token: or, True Label: O, Predicted Label: O
#
# Example 713 - Correct Predictions:
# Token: that, True Label: O, Predicted Label: O
#
# Example 714 - Correct Predictions:
# Token: had, True Label: O, Predicted Label: O
#
# Example 715 - Correct Predictions:
# Token: ceased, True Label: O, Predicted Label: O
#
# Example 716 - Correct Predictions:
# Token: to, True Label: O, Predicted Label: O
#
# Example 717 - Correct Predictions:
# Token: be, True Label: O, Predicted Label: O
#
# Example 718 - Correct Predictions:
# Token: shareholders, True Label: O, Predicted Label: O
#
# Example 719 - Correct Predictions:
# Token: since, True Label: O, Predicted Label: O
#
# Example 720 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 721 - Correct Predictions:
# Token: made, True Label: O, Predicted Label: O
#
# Example 722 - Correct Predictions:
# Token: up, True Label: O, Predicted Label: O
#
# Example 723 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 724 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 725 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 726 - Correct Predictions:
# Token: previous, True Label: O, Predicted Label: O
#
# Example 727 - Correct Predictions:
# Token: Annual, True Label: O, Predicted Label: O
#
# Example 728 - Correct Predictions:
# Token: Return, True Label: O, Predicted Label: O
#
# Example 729 - Correct Predictions:
# Token: A, True Label: O, Predicted Label: O
#
# Example 730 - Correct Predictions:
# Token: full, True Label: O, Predicted Label: O
#
# Example 731 - Correct Predictions:
# Token: list, True Label: O, Predicted Label: O
#
# Example 732 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 733 - Correct Predictions:
# Token: shareholders, True Label: O, Predicted Label: O
#
# Example 734 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 735 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 736 - Correct Predictions:
# Token: company, True Label: O, Predicted Label: O
#
# Example 737 - Correct Predictions:
# Token: are, True Label: O, Predicted Label: O
#
# Example 738 - Correct Predictions:
# Token: shown, True Label: O, Predicted Label: O
#
# Example 739 - Correct Predictions:
# Token: below, True Label: O, Predicted Label: O
#
# Example 740 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 741 - Correct Predictions:
# Token: 7, True Label: O, Predicted Label: O
#
# Example 742 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 743 - Correct Predictions:
# Token: 46734, True Label: O, Predicted Label: O
#
# Example 744 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 745 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 746 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 747 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 748 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 749 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 750 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 751 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 752 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 753 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 754 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 755 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 756 - Correct Predictions:
# Token: BRIGHT, True Label: O, Predicted Label: O
#
# Example 757 - Correct Predictions:
# Token: FUTURE, True Label: O, Predicted Label: O
#
# Example 758 - Correct Predictions:
# Token: SOLUTIONS, True Label: O, Predicted Label: O
#
# Example 759 - Correct Predictions:
# Token: LIMITED, True Label: O, Predicted Label: O
#
# Example 760 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 761 - Correct Predictions:
# Token: 8, True Label: O, Predicted Label: O
#
# Example 762 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 763 - Correct Predictions:
# Token: 4799, True Label: O, Predicted Label: O
#
# Example 764 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 765 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 766 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 767 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 768 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 769 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 770 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 771 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 772 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 773 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 774 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 775 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 776 - Correct Predictions:
# Token: THOMAS, True Label: O, Predicted Label: O
#
# Example 777 - Correct Predictions:
# Token: HARRIS, True Label: O, Predicted Label: O
#
# Example 778 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 779 - Correct Predictions:
# Token: 9, True Label: O, Predicted Label: O
#
# Example 780 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 781 - Correct Predictions:
# Token: 6561, True Label: O, Predicted Label: O
#
# Example 782 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 783 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 784 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 785 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 786 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 787 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 788 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 789 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 790 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 791 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 792 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 793 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 794 - Correct Predictions:
# Token: EDWARD, True Label: O, Predicted Label: O
#
# Example 795 - Correct Predictions:
# Token: MOORE, True Label: O, Predicted Label: O
#
# Example 796 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 797 - Correct Predictions:
# Token: 10, True Label: O, Predicted Label: O
#
# Example 798 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 799 - Correct Predictions:
# Token: 13702, True Label: O, Predicted Label: O
#
# Example 800 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 801 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 802 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 803 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 804 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 805 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 806 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 807 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 808 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 809 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 810 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 811 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 812 - Correct Predictions:
# Token: JOSEPH, True Label: O, Predicted Label: O
#
# Example 813 - Correct Predictions:
# Token: GARCIA, True Label: O, Predicted Label: O
#
# Example 814 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 815 - Correct Predictions:
# Token: 11, True Label: O, Predicted Label: O
#
# Example 816 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 817 - Correct Predictions:
# Token: 733, True Label: O, Predicted Label: O
#
# Example 818 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 819 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 820 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 821 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 822 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 823 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 824 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 825 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 826 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 827 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 828 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 829 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 830 - Correct Predictions:
# Token: EDWARD, True Label: O, Predicted Label: O
#
# Example 831 - Correct Predictions:
# Token: SMITH, True Label: O, Predicted Label: O
#
# Example 832 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 833 - Correct Predictions:
# Token: 12, True Label: O, Predicted Label: O
#
# Example 834 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 835 - Correct Predictions:
# Token: 784, True Label: O, Predicted Label: O
#
# Example 836 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 837 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 838 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 839 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 840 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 841 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 842 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 843 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 844 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 845 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 846 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 847 - Correct Predictions:
# Token: GLOBAL, True Label: O, Predicted Label: O
#
# Example 848 - Correct Predictions:
# Token: ENTERPRISES, True Label: O, Predicted Label: O
#
# Example 849 - Correct Predictions:
# Token: INCORPORATED, True Label: O, Predicted Label: O
#
# Example 850 - Correct Predictions:
# Token: Shareholding, True Label: O, Predicted Label: O
#
# Example 851 - Correct Predictions:
# Token: 13, True Label: O, Predicted Label: O
#
# Example 852 - Correct Predictions:
# Token: ;, True Label: O, Predicted Label: O
#
# Example 853 - Correct Predictions:
# Token: 4438, True Label: O, Predicted Label: O
#
# Example 854 - Correct Predictions:
# Token: ORDINARY, True Label: O, Predicted Label: O
#
# Example 855 - Correct Predictions:
# Token: B, True Label: O, Predicted Label: O
#
# Example 856 - Correct Predictions:
# Token: shares, True Label: O, Predicted Label: O
#
# Example 857 - Correct Predictions:
# Token: held, True Label: O, Predicted Label: O
#
# Example 858 - Correct Predictions:
# Token: as, True Label: O, Predicted Label: O
#
# Example 859 - Correct Predictions:
# Token: at, True Label: O, Predicted Label: O
#
# Example 860 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 861 - Correct Predictions:
# Token: date, True Label: O, Predicted Label: O
#
# Example 862 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 863 - Correct Predictions:
# Token: this, True Label: O, Predicted Label: O
#
# Example 864 - Correct Predictions:
# Token: return, True Label: O, Predicted Label: O
#
# Example 865 - Correct Predictions:
# Token: Name:, True Label: O, Predicted Label: O
#
# Example 866 - Correct Predictions:
# Token: MICHAEL, True Label: O, Predicted Label: O
#
# Example 867 - Correct Predictions:
# Token: MOORE, True Label: O, Predicted Label: O
#
# Example 868 - Correct Predictions:
# Token: Authorisation, True Label: O, Predicted Label: O
#
# Example 869 - Correct Predictions:
# Token: Authenticated, True Label: O, Predicted Label: O
#
# Example 870 - Correct Predictions:
# Token: This, True Label: O, Predicted Label: O
#
# Example 871 - Correct Predictions:
# Token: form, True Label: O, Predicted Label: O
#
# Example 872 - Correct Predictions:
# Token: was, True Label: O, Predicted Label: O
#
# Example 873 - Correct Predictions:
# Token: authorised, True Label: O, Predicted Label: O
#
# Example 874 - Correct Predictions:
# Token: by, True Label: O, Predicted Label: O
#
# Example 875 - Correct Predictions:
# Token: one, True Label: O, Predicted Label: O
#
# Example 876 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 877 - Correct Predictions:
# Token: the, True Label: O, Predicted Label: O
#
# Example 878 - Correct Predictions:
# Token: following:, True Label: O, Predicted Label: O
#
# Example 879 - Correct Predictions:
# Token: Director, True Label: O, Predicted Label: O
#
# Example 880 - Correct Predictions:
# Token: Secretary, True Label: O, Predicted Label: O
#
# Example 881 - Correct Predictions:
# Token: Person, True Label: O, Predicted Label: O
#
# Example 882 - Correct Predictions:
# Token: Authorised, True Label: O, Predicted Label: O
#
# Example 883 - Correct Predictions:
# Token: Charity, True Label: O, Predicted Label: O
#
# Example 884 - Correct Predictions:
# Token: Commission, True Label: O, Predicted Label: O
#
# Example 885 - Correct Predictions:
# Token: Receiver, True Label: O, Predicted Label: O
#
# Example 886 - Correct Predictions:
# Token: and, True Label: O, Predicted Label: O
#
# Example 887 - Correct Predictions:
# Token: Manager, True Label: O, Predicted Label: O
#
# Example 888 - Correct Predictions:
# Token: CIC, True Label: O, Predicted Label: O
#
# Example 889 - Correct Predictions:
# Token: Manager, True Label: O, Predicted Label: O
#
# Example 890 - Correct Predictions:
# Token: Judicial, True Label: O, Predicted Label: O
#
# Example 891 - Correct Predictions:
# Token: Factor., True Label: O, Predicted Label: O
#
# Example 892 - Correct Predictions:
# Token: End, True Label: O, Predicted Label: O
#
# Example 893 - Correct Predictions:
# Token: of, True Label: O, Predicted Label: O
#
# Example 894 - Correct Predictions:
# Token: Electronically, True Label: O, Predicted Label: O
#
# Example 895 - Correct Predictions:
# Token: Filed, True Label: O, Predicted Label: O
#
# Example 896 - Correct Predictions:
# Token: Document, True Label: O, Predicted Label: O
#
# Example 897 - Correct Predictions:
# Token: for, True Label: O, Predicted Label: O
#
# Example 898 - Correct Predictions:
# Token: Company, True Label: O, Predicted Label: O
#
# Example 899 - Correct Predictions:
# Token: Number:, True Label: O, Predicted Label: O
#
# Example 900 - Correct Predictions:
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 901 - Correct Predictions:
# Token: Page:9, True Label: O, Predicted Label: O

# %%
# Iterate through each example and display only correct predictions (excluding "O" labels)
for i in range(len(test_sentence_token_labels)):
    tokens = test_sentence_token_labels[i][0]
    true_label_sequence = true_labels[i]
    pred_label_sequence = pred_labels[i]

    # Filter correct predictions where true label matches predicted label and is not "O"
    correct_predictions = [
        (token, true_label, pred_label)
        for token, true_label, pred_label in zip(tokens, true_label_sequence, pred_label_sequence)
        if true_label == pred_label and true_label != "O"
    ]

    # Display correct predictions for the current example
    if correct_predictions:
        print(f"Example {i + 1} - Correct Predictions (Excluding 'O'):")
        for token, true_label, pred_label in correct_predictions:
            print(f"Token: {token}, True Label: {true_label}, Predicted Label: {pred_label}")
        print()
# Out:
# Example 3 - Correct Predictions (Excluding 'O'):
# Token: 13/04/2022, True Label: B-[FILING_DATE], Predicted Label: B-[FILING_DATE]
# Token: ALLIANCE, True Label: B-[COMPANY_NAME], Predicted Label: B-[COMPANY_NAME]
# Token: PARTNERS, True Label: I-[COMPANY_NAME], Predicted Label: I-[COMPANY_NAME]
# Token: LIMITED, True Label: I-[COMPANY_NAME], Predicted Label: I-[COMPANY_NAME]
# Token: 71027, True Label: B-[SIC_CODES], Predicted Label: B-[SIC_CODES]
# Token: LIMITED, True Label: B-[COMPANY_TYPE], Predicted Label: B-[COMPANY_TYPE]
# Token: Victoria, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Street, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Brighton, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: X34, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: 8AT, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
# Token: Kingdom, True Label: I-[REGISTERED_ADDRESS], Predicted Label: I-[REGISTERED_ADDRESS]
#
# Example 5 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 45 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 94 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 162 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 232 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 302 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 341 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 691 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]
#
# Example 900 - Correct Predictions (Excluding 'O'):
# Token: 8283180, True Label: B-[COMPANY_NUMBER], Predicted Label: B-[COMPANY_NUMBER]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Flatten the lists to calculate metrics at the token level
flattened_true_labels = []
flattened_pred_labels = []

for true_seq, pred_seq in zip(true_labels, pred_labels):
    for true_label, pred_label in zip(true_seq, pred_seq):
        if true_label != "O":  # Exclude "O" for precision, recall, and F1
            flattened_true_labels.append(true_label)
            flattened_pred_labels.append(pred_label)

# Calculate token-level accuracy, including "O" labels
flattened_all_true_labels = [label for seq in true_labels for label in seq]
flattened_all_pred_labels = [label for seq in pred_labels for label in seq]
accuracy = accuracy_score(flattened_all_true_labels, flattened_all_pred_labels)

# Calculate precision, recall, and F1 score for entity labels only
precision = precision_score(flattened_true_labels, flattened_pred_labels, average="weighted")
recall = recall_score(flattened_true_labels, flattened_pred_labels, average="weighted")
f1 = f1_score(flattened_true_labels, flattened_pred_labels, average="weighted")

# Display the metrics
print(f"Accuracy (including 'O' labels): {accuracy:.4f}")
print(f"Precision (entities only): {precision:.4f}")
print(f"Recall (entities only): {recall:.4f}")
print(f"F1 Score (entities only): {f1:.4f}")
# Out:
# Accuracy (including 'O' labels): 0.9999
# Precision (entities only): 0.8889
# Recall (entities only): 0.7778
# F1 Score (entities only): 0.8200
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import torch
from transformers import BertForTokenClassification, BertTokenizer
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from torch.utils.data import DataLoader

# Initialize base BERT model for token classification
base_model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=len(label2id))
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Define the NERDataset class (reused from training code)
class NERDataset(torch.utils.data.Dataset):
    def __init__(self, input_ids, attention_masks, label_ids):
        self.input_ids = input_ids
        self.attention_masks = attention_masks
        self.label_ids = label_ids

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
            'labels': torch.tensor(self.label_ids[idx], dtype=torch.long)
        }

# Prepare the test dataset and dataloader
test_dataset = NERDataset(test_input_ids, test_attention_masks, test_label_ids)
test_dataloader = DataLoader(test_dataset, batch_size=8)

# Make predictions with the base model
base_model.eval()
pred_labels = []
true_labels = []

with torch.no_grad():
    for batch in test_dataloader:
        input_ids = batch['input_ids']
        attention_mask = batch['attention_mask']
        labels = batch['labels']

        # Get model outputs
        outputs = base_model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits

        # Get predicted labels
        predictions = torch.argmax(logits, dim=-1)

        # Flatten and filter out padding tokens for both predictions and labels
        for i in range(predictions.shape[0]):  # Iterate over each example in the batch
            active_labels = labels[i][attention_mask[i] == 1]  # Only non-padding positions
            active_preds = predictions[i][attention_mask[i] == 1]

            pred_labels.extend(active_preds.cpu().numpy())
            true_labels.extend(active_labels.cpu().numpy())

# Convert numeric labels back to names for calculating metrics
pred_label_names = [id2label[label] for label in pred_labels]
true_label_names = [id2label[label] for label in true_labels]

# Calculate accuracy (including "O" labels)
accuracy = accuracy_score(true_label_names, pred_label_names)

# Calculate precision, recall, and F1 score for entity labels only (excluding "O")
non_o_true_labels = [label for label in true_label_names if label != "O"]
non_o_pred_labels = [label for label, true in zip(pred_label_names, true_label_names) if true != "O"]

precision = precision_score(non_o_true_labels, non_o_pred_labels, average="weighted")
recall = recall_score(non_o_true_labels, non_o_pred_labels, average="weighted")
f1 = f1_score(non_o_true_labels, non_o_pred_labels, average="weighted")

# Display the metrics
print(f"Accuracy (including 'O' labels): {accuracy:.4f}")
print(f"Precision (entities only): {precision:.4f}")
print(f"Recall (entities only): {recall:.4f}")
print(f"F1 Score (entities only): {f1:.4f}")
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Accuracy (including 'O' labels): 0.0476
# Precision (entities only): 0.0000
# Recall (entities only): 0.0000
# F1 Score (entities only): 0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
